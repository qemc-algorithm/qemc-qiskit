# %%
import json
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt


root_data_path = Path(
    "/home/ohad/work/quantum_variational_combinatorial_optimization/qemc/",
    "EXP_DATA",
    "ref_29_table3_comparison",
)

graph_names = [
    "graph_random_graph__p_0.600__density_0.60__seed_0"
]

for graph_name in graph_names:
#     data_path = Path(
#         root_data_path,
#         graph_name,
#         "backend_statevector_simulator"
#     )
    
#     specific_data_path = Path(
#         root_data_path,
#         graph_name,
#         "backend_statevector_simulator/blue_nodes_None/num_layers_13/shots_None/rhobeg_1/configuration_data.csv"
#     )

#     exp_data = pd.read_csv(specific_data_path)

    nodes_32_data_path = Path(
        "/home/ohad/work/quantum_variational_combinatorial_optimization/qemc/EXP_DATA/ref_29_fig3b_comparison/graph_random_graph__p_0.660__density_0.65__seed_0/backend_statevector_simulator/blue_nodes_None/num_layers_5/shots_None/rhobeg_1/configuration_data.csv"
    )
    exp_data_32 = pd.read_csv(nodes_32_data_path)

# exp_data
exp_data_32
# Out:
#      Unnamed: 0  sample_0_costs  sample_0_cuts  sample_1_costs  sample_1_cuts  \
# 0             0        1.245587            153        1.394449            141
# 1             1        1.245587            153        1.394449            141
# 2             2        2.531091            149        1.091435            157
# 3             3        1.389961            147        1.023161            148
# 4             4        1.245587            153        1.023161            148
# ..          ...             ...            ...             ...            ...
# 745         745        0.715069            184        0.712838            187
# 746         746        0.714939            184        0.712122            187
# 747         747        0.714798            184        0.712628            187
# 748         748        0.714761            184        0.712059            187
# 749         749        0.715292            184        0.712548            187
#
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(range(1000), exp_data["sample_0_costs"])

# %%
plt.plot(range(750), exp_data_32["sample_0_costs"])
