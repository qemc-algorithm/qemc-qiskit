# %% [markdown]
# # Memory Advantage in the QEMC Algorithm? Notebook 2

# %% [markdown]
# **Ohad Lev**
#
# **September 2023**

# %% [markdown]
# We make use of the same function that generates a graph strucure "on the fly" as in the previous notebook:

# %%
import networkx as nx


def edges_generator(node_index, num_nodes):

    gen_edges = []
    gen_edges.append((node_index, (node_index + 1) % num_nodes))
    gen_edges.append((node_index, (node_index + 2) % num_nodes))
    
    return gen_edges


num_nodes = 8

edges = []
for index in range(num_nodes):
    edges += edges_generator(index, num_nodes)

graph = nx.Graph(edges)
nx.draw(graph, with_labels=True)

print(edges)
# Out:
# [(0, 1), (0, 2), (1, 2), (1, 3), (2, 3), (2, 4), (3, 4), (3, 5), (4, 5), (4, 6), (5, 6), (5, 7), (6, 7), (6, 0), (7, 0), (7, 1)]

# %% [markdown]
# Let's write again the cost function of the QEMC algorithm:

# %% [markdown]
# $$ C(G) = \sum^{}_{i < j} \Bigg( p_i + p_j - \frac{1}{B} \Bigg)^2 + \Bigg( |p_i - p_j| - \frac{1}{B} \Bigg)^2 $$

# %% [markdown]
# But now, on the contrary to notebook 1, we assign the rest of $N - B$ nodes (of which we do not save the probabilities for) with an average residual probability of $\frac{1 - P}{N - B}$ each, where $P$ is the sum of probabilities associated with the $B$ mose probable nodes.

# %% [markdown]
# ### Brute-Force MaxCut

# %%
# Brute Force

from classical_functions import brute_force_maxcut


bfmc = brute_force_maxcut(graph)

print(bfmc.optimal_partitions)
print(bfmc.best_score)
# Out:
# {'00110011', '10011001', '01100110', '11001100'}
# 12

# %% [markdown]
# ### MaxCut approximation by the original QEMC

# %%
# Origianl QEMC

from qemc_implementation import QEMC


qemc_int = QEMC(graph)
qemc_int.construct_ansatz(6)
qemc_int.run()
# Out:
# QEMCResult(optimizer_result= message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 0.4014892578125
#        x: [ 1.011e+00  5.916e+00 ...  1.668e+00  2.430e+00]
#     nfev: 501
#    maxcv: 0.0, best_counts={'100': 31, '111': 19, '011': 59, '000': 113, '010': 313, '110': 150, '001': 162, '101': 177}, best_params=array([0.98943532, 5.93476685, 0.67184862, 6.40677954, 6.121481  ,
#        1.93973598, 1.00846885, 2.31650743, 3.01888637, 2.10531211,
#        3.27229038, 4.72053617, 4.65232617, 3.55692447, 5.21725391,
#        1.94995994, 0.20372732, 0.80528683, 0.38942018, 1.97084005,
#        1.20907251, 2.97692648, 3.87978461, 0.29370056, 1.05533585,
#        3.68371541, 3.6876733 , 2.62479181, 4.22466254, 4.65347084,
#        5.7101838 , 4.78793257, 4.33460024, 1.16264983, 3.43514183,
#        6.14258597, 5.3428482 , 5.40452506, 1.11528237, 6.24346537,
#        1.12235665, 0.50553869, 5.82112091, 4.34176398, 1.27610767,
#        0.37650393, 3.322081  , 0.4951879 , 0.51833133, 3.76051008,
#        2.35435392, 2.53761814, 1.58049747, 2.43284801]), best_cost_value=32, best_partition_bitstring='01100110', best_score=12)

# %% [markdown]
# Achieved an optimal partition.

# %% [markdown]
# ### Modified QEMC to test possible memory advantage

# %%
# Setting memory limitation to B = 4, 1024 shots

from qemc_memory_adv_implementation import QEMC_ML

qemc_ml_int = QEMC_ML(graph)
qemc_ml_int.construct_ansatz(6)
qemc_ml_int.run(memory_limitation=4)
# Out:
# {'111': 0.2724609375, '011': 0.2099609375, '001': 0.1884765625, '110': 0.162109375, '000': 0.041748046875, '101': 0.041748046875, '100': 0.041748046875, '010': 0.041748046875}
# QEMCResult(optimizer_result= message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 0.5304718017578125
#        x: [ 3.341e+00  4.307e+00 ...  5.117e+00  1.499e-01]
#     nfev: 499
#    maxcv: 0.0, best_counts={'111': 0.2724609375, '011': 0.2099609375, '001': 0.1884765625, '110': 0.162109375, '000': 0.041748046875, '101': 0.041748046875, '100': 0.041748046875, '010': 0.041748046875}, best_params=array([3.33719473, 4.31279082, 6.09223558, 1.7631417 , 0.86469763,
#        3.90258429, 0.75002906, 5.51158053, 1.70379093, 1.16186304,
#        2.35966885, 3.20732984, 1.40411485, 6.09136912, 0.71131428,
#        5.81091991, 1.46032473, 3.1198074 , 1.83194042, 4.15701019,
#        2.24115535, 0.79368155, 1.59660013, 1.48369865, 1.28110194,
#        1.07947157, 2.75951113, 3.4639289 , 3.4451376 , 4.34426963,
#        4.52995366, 3.44932585, 3.32366834, 0.85307229, 6.27400952,
#        4.51021868, 3.69850022, 2.93876199, 3.92658321, 4.03690234,
#        1.48146687, 4.01921259, 4.22239568, 4.0988401 , 5.69486214,
#        2.55599295, 4.46147032, 4.58898633, 2.56233409, 3.51962058,
#        2.76244951, 2.88999104, 5.12587413, 0.14867465]), best_cost_value=32, best_partition_bitstring='11001010', best_score=10)

# %% [markdown]
# ----------

# %% [markdown]
# ## Larger Graph-Instance

# %%
num_nodes = 16

edges = []
for i in range(num_nodes):
    edges += edges_generator(i, num_nodes)
    
graph = nx.Graph(edges)
nx.draw(graph, with_labels=True)

# %%
bfmc = brute_force_maxcut(graph)

print(bfmc.optimal_partitions)
print(bfmc.best_score)
# Out:
# {'1001100110011001', '1100110011001100', '0110011001100110', '0011001100110011'}
# 24

# %%
qemc_int = QEMC(graph)
qemc_int.construct_ansatz(6)
qemc_org_version_res = qemc_int.run()
qemc_org_version_res
# Out:
# QEMCResult(optimizer_result= message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 0.2194671630859375
#        x: [ 2.359e+00  5.770e+00 ...  5.359e+00  2.937e+00]
#     nfev: 654
#    maxcv: 0.0, best_counts={'0001': 15, '1100': 5, '0010': 25, '1011': 91, '0011': 83, '0111': 124, '1111': 157, '0000': 54, '1010': 106, '1101': 23, '1000': 63, '0110': 41, '1110': 136, '1001': 23, '0101': 7, '0100': 71}, best_params=array([2.25072321, 5.75619881, 5.76723523, 4.59064308, 2.30246485,
#        4.10860604, 3.91398967, 1.95880213, 5.92412548, 0.15125947,
#        0.17388095, 2.41512753, 1.73100936, 4.40440314, 4.97477595,
#        3.48226003, 3.7741127 , 1.13148909, 0.53347787, 4.18008716,
#        2.36713911, 2.57583599, 1.90312991, 4.36190345, 5.00718026,
#        1.70420457, 6.27262614, 4.30737185, 5.85858229, 2.65275335,
#        5.24047639, 1.91442168, 2.16273903, 3.80186387, 6.01152485,
#        0.90838576, 2.68084304, 4.54098162, 1.72158034, 0.26879815,
#        0.35534334, 4.96771006, 2.19619681, 2.46680122, 4.69971579,
#        5.98226323, 1.71202866, 4.89688575, 4.43535989, 6.11785428,
#        3.53192635, 3.04501958, 1.01835629, 6.27843504, 5.43988423,
#        3.3275253 , 3.96885642, 3.22432106, 5.81290979, 3.24975011,
#        1.54155245, 1.4016368 , 3.46603531, 2.68263531, 3.67725322,
#        0.26437223, 5.571866  , 0.38140848, 1.23758425, 3.98188672,
#        5.37993722, 1.91921269]), best_cost_value=64, best_partition_bitstring='1100110010011000', best_score=22)

# %% [markdown]
# Memory limit version:

# %%
qemc_ml_int = QEMC_ML(graph)
qemc_ml_int.construct_ansatz(6)
qemc_ml_version_res = qemc_ml_int.run(memory_limitation=8)
qemc_ml_version_res
# Out:
# {'0100': 0.15234375, '1101': 0.150390625, '0001': 0.1220703125, '0000': 0.09375, '1100': 0.0732421875, '0011': 0.0693359375, '1001': 0.068359375, '0111': 0.0673828125, '1011': 0.025390625, '1111': 0.025390625, '0110': 0.025390625, '1000': 0.025390625, '1110': 0.025390625, '0101': 0.025390625, '1010': 0.025390625, '0010': 0.025390625}
# QEMCResult(optimizer_result= message: Optimization terminated successfully.
#  success: True
#   status: 1
#      fun: 0.26184940338134766
#        x: [ 5.440e+00  2.616e+00 ...  3.419e+00  5.046e+00]
#     nfev: 608
#    maxcv: 0.0, best_counts={'0100': 0.15234375, '1101': 0.150390625, '0001': 0.1220703125, '0000': 0.09375, '1100': 0.0732421875, '0011': 0.0693359375, '1001': 0.068359375, '0111': 0.0673828125, '1011': 0.025390625, '1111': 0.025390625, '0110': 0.025390625, '1000': 0.025390625, '1110': 0.025390625, '0101': 0.025390625, '1010': 0.025390625, '0010': 0.025390625}, best_params=array([5.44127341, 2.62054895, 4.02633296, 1.41463595, 4.3823547 ,
#        5.46820033, 5.26942328, 3.22027462, 4.08573724, 5.67202741,
#        3.97397933, 1.86773334, 4.51473562, 2.93624934, 0.89010937,
#        6.21851834, 3.5375572 , 5.14854798, 6.04044745, 4.61252893,
#        2.43017395, 3.83590081, 2.80862107, 5.95826428, 3.24842907,
#        3.48431621, 3.46721471, 2.11764946, 1.09947595, 5.70222772,
#        1.77387093, 1.25074889, 2.49104259, 5.71605733, 1.2020148 ,
#        5.2613493 , 5.58388962, 2.52068057, 2.76973017, 3.25205576,
#        0.86634745, 3.10948036, 4.46965085, 2.4701317 , 3.82758941,
#        4.0667516 , 1.55459633, 3.47199365, 3.56285484, 2.20651071,
#        0.01486942, 0.14076987, 2.50489034, 2.63600529, 1.07316294,
#        2.57682113, 2.6469372 , 5.24304943, 0.24933491, 4.15512063,
#        3.82354113, 3.76300437, 5.00554517, 3.36063004, 4.90260845,
#        5.19443966, 4.94401592, 5.42469321, 0.45733888, 0.57894844,
#        3.42696534, 5.17227514]), best_cost_value=64, best_partition_bitstring='0011001010011011', best_score=22)

# %%
from qiskit.visualization import plot_distribution

plot_distribution(qemc_ml_version_res.best_counts)

# %%
import numpy as np
import matplotlib.pyplot as plt


qemc_iters = len(qemc_int.cut_scores)
qemc_ml_iters = len(qemc_ml_int.cut_scores)
iters_diff = np.abs(qemc_iters - qemc_ml_iters)
x = range(max(qemc_iters, qemc_ml_iters))

if qemc_iters > qemc_ml_iters:
    qemc_ml_int.cut_scores.extend(
        [qemc_ml_int.cut_scores[-1] for _ in range(iters_diff)]
    )
else:
    qemc_int.cut_scores.extend(
        [qemc_int.cut_scores[-1] for _ in range(iters_diff)]
    )


plt.plot(x, qemc_int.cut_scores, label="org_qemc")
plt.plot(x, qemc_ml_int.cut_scores, label="memory_limit_qemc")

plt.legend()

# %% [markdown]
# ----------------

# %% [markdown]
# ## Larger (brute-force intractable) instances

# %%
num_nodes = 128

edges = []
for i in range(num_nodes):
    edges += edges_generator(i, num_nodes)
    
graph = nx.Graph(edges)
nx.draw(graph, with_labels=True)

# %%
qemc_int = QEMC(graph)
qemc_int.construct_ansatz(10)
qemc_org_version_res = qemc_int.run()
qemc_org_version_res
# Out:
# QEMCResult(optimizer_result= message: Maximum number of function evaluations has been exceeded.
#  success: False
#   status: 2
#      fun: 0.0405120849609375
#        x: [ 2.919e+00  6.752e+00 ...  3.769e+00  3.461e+00]
#     nfev: 1000
#    maxcv: 0.0, best_counts={'0001101': 1, '1000000': 1, '0001001': 6, '0000111': 2, '0111111': 1, '0101101': 1, '0110111': 3, '0111110': 5, '0111101': 10, '1010000': 3, '1001010': 3, '0001000': 12, '1001001': 2, '0101110': 15, '0110000': 4, '1100101': 3, '1100010': 11, '1101101': 11, '1110000': 2, '0100100': 6, '1011110': 7, '1001011': 14, '0011001': 4, '0101000': 5, '0111011': 1, '0011000': 4, '0001011': 4, '1110111': 2, '0101011': 8, '1010010': 3, '0100011': 12, '0110110': 8, '1111011': 11, '0010110': 3, '1010110': 3, '1010011': 14, '0100000': 11, '0100110': 11, '1111111': 4, '1000010': 18, '1111100': 6, '1101011': 14, '0010000': 15, '1011001': 5, '1101000': 5, '1010101': 2, '1000111': 5, '1010100': 21, '0100111': 6, '0000100': 24, '1000100': 3, '1111010': 4, '1000101': 20, '1100100': 16, '1100000': 5, '1110110': 8, '1111001': 9, '0000011': 19, '0001010': 21, '1101110': 29, '0111001': 12, '1000110': 23, '0011111': 9, '1100110': 9, '1011100': 6, '0010001': 15, '0000110': 11, '1110001': 9, '1111110': 9, '1110101': 5, '0110011': 7, '1001100': 8, '0010010': 11, '1010001': 9, '0111000': 8, '0100010': 7, '0011110': 8, '1011101': 8, '0000010': 11, '1110010': 13, '1011011': 11, '0010011': 3, '0010111': 1, '1110100': 6, '0010101': 11, '0100001': 5, '1011010': 12, '0111100': 15, '1100011': 11, '0100101': 7, '1011111': 8, '0011011': 16, '1101010': 18, '0101100': 15, '0101010': 2, '1001110': 14, '0001111': 4, '0011100': 3, '0110010': 16, '0010100': 28, '1000011': 7, '0101111': 6, '0101001': 7, '1111101': 5, '1110011': 1, '0001110': 16, '0001100': 1, '1100001': 1, '1101100': 7, '1010111': 15, '0110001': 21, '0111010': 1, '0110100': 8, '0000001': 2, '1100111': 6, '0011101': 6, '0011010': 20, '1001000': 4}, best_params=array([2.90242573, 6.73242522, 5.53468345, 6.51298071, 2.33474548,
#        3.01777073, 0.48703822, 3.47680325, 3.1324368 , 4.21844652,
#        5.4887102 , 5.42091614, 4.56008443, 3.91763422, 1.22568886,
#        4.47310135, 3.65691656, 2.84456883, 1.97281997, 5.3926179 ,
#        5.78733772, 3.31056066, 1.78309435, 2.48701187, 4.60441588,
#        2.96617682, 2.44728903, 0.72948652, 1.05569605, 4.13299315,
#        0.52805257, 3.23948103, 3.01232937, 5.334203  , 4.07813854,
#        0.94199658, 2.39649753, 1.87036477, 5.77021333, 6.03600993,
#        1.22508719, 0.9560521 , 1.7262008 , 0.48427023, 2.46394338,
#        5.91310344, 1.07975938, 4.14682315, 1.18009477, 6.06995443,
#        1.32888426, 3.90370502, 1.57441409, 3.99064379, 3.0390951 ,
#        2.36365481, 2.49883332, 4.90786907, 4.6642709 , 0.06880577,
#        0.39319438, 2.86870583, 5.8313423 , 3.97062391, 2.49456253,
#        2.98230947, 3.42341801, 2.69512078, 4.51893999, 5.26648436,
#        6.20157397, 4.13071718, 0.53964093, 5.21158978, 2.29836845,
#        0.526938  , 1.63722127, 0.17924724, 5.63631387, 2.26304923,
#        1.85239016, 2.34855205, 4.94704886, 5.31129018, 0.93101967,
#        6.2164596 , 0.41819084, 3.09966528, 2.50223627, 4.60076063,
#        5.12782254, 3.28774561, 4.19735816, 4.29643182, 5.12399298,
#        0.9140879 , 1.1777821 , 3.23462658, 3.88040315, 3.38706156,
#        2.91378224, 5.51170843, 5.5403165 , 5.91838775, 2.398872  ,
#        1.79509157, 5.49886216, 2.70465804, 1.49533936, 0.40121858,
#        1.19526294, 1.20292858, 2.70176793, 1.61558153, 4.24196906,
#        5.71765135, 3.1665693 , 4.18019328, 5.35865287, 5.45563785,
#        5.83116393, 3.14614624, 2.10672802, 4.80271153, 0.4444957 ,
#        2.1374736 , 2.38690469, 2.60643446, 1.21277423, 3.33020735,
#        1.73347726, 2.71109425, 2.72833155, 5.89898683, 3.79808172,
#        4.27290864, 2.73775888, 2.98923915, 6.23129205, 3.62777827,
#        3.66585387, 3.40663722, 5.0192176 , 5.41178656, 1.98261107,
#        3.61515426, 5.59321242, 3.2026361 , 1.95395489, 1.15793557,
#        3.12299075, 2.95978193, 4.01013518, 0.43317784, 1.05961017,
#        3.40210255, 3.04352273, 0.82153638, 6.25842174, 3.79215521,
#        0.66005462, 1.39423269, 2.630769  , 2.99914567, 3.46071632,
#        5.31069533, 3.03445639, 2.28020381, 1.17718732, 2.81959957,
#        5.33916946, 5.91709031, 4.66763344, 5.27249167, 5.09382863,
#        7.18597744, 1.41054344, 2.65533106, 5.07442507, 2.59945948,
#        6.13850828, 4.23906462, 6.23964171, 2.28684583, 2.09669731,
#        3.74521018, 4.0547662 , 4.4144728 , 5.38079451, 5.60681465,
#        4.56718839, 5.53980405, 1.02653435, 0.2344511 , 3.27815465,
#        2.3133493 , 2.14235184, 5.96514033, 4.87290972, 5.3131395 ,
#        0.05812421, 5.27130614, 3.45428282, 2.02144639, 2.9770235 ,
#        5.04546587, 6.02408553, 0.46412001, 3.7593752 , 3.45088522]), best_cost_value=512, best_partition_bitstring='01001010010001100110110001011100101011001001101001011000011001000011001101010110010110000100100111001100001101110100010101011100', best_score=150)

# %% [markdown]
# Memory limit version:

# %%
qemc_ml_int = QEMC_ML(graph)
qemc_ml_int.construct_ansatz(10)
qemc_ml_version_res = qemc_ml_int.run(memory_limitation=num_nodes / 2)
qemc_ml_version_res
# Out:
# {'1010111': 0.03125, '1101110': 0.0302734375, '0011101': 0.025390625, '1110001': 0.0234375, '0100101': 0.01953125, '1001100': 0.0185546875, '1101000': 0.0185546875, '1010001': 0.017578125, '1111110': 0.0166015625, '1000111': 0.0166015625, '0000010': 0.0166015625, '0110001': 0.0166015625, '1100000': 0.015625, '1111101': 0.0146484375, '1011111': 0.0146484375, '1100110': 0.0146484375, '0100000': 0.0146484375, '1111001': 0.0146484375, '0100010': 0.0146484375, '1100100': 0.0146484375, '0001101': 0.013671875, '1110100': 0.013671875, '0110010': 0.013671875, '0000110': 0.0126953125, '0010111': 0.0126953125, '0100001': 0.0126953125, '1000101': 0.01171875, '0011001': 0.01171875, '1001001': 0.01171875, '0011110': 0.01171875, '1111010': 0.01171875, '0111001': 0.01171875, '0011010': 0.01171875, '1100011': 0.0107421875, '1010011': 0.0107421875, '1011101': 0.0107421875, '0100110': 0.0107421875, '0011011': 0.009765625, '0010000': 0.009765625, '1100001': 0.009765625, '0111011': 0.009765625, '0001110': 0.009765625, '1011000': 0.009765625, '1000100': 0.009765625, '0000001': 0.009765625, '0101010': 0.0087890625, '1011100': 0.0087890625, '0010101': 0.0087890625, '0000111': 0.0087890625, '0101110': 0.0087890625, '1000001': 0.0078125, '0010001': 0.0078125, '1110101': 0.0078125, '0101101': 0.0078125, '0010011': 0.0078125, '1011011': 0.0078125, '1010010': 0.0078125, '0111111': 0.0078125, '1101011': 0.0078125, '0101001': 0.0078125, '0111000': 0.0078125, '1010101': 0.0078125, '1001101': 0.0068359375, '1100101': 0.0068359375, '0000100': 0.003082275390625, '1100010': 0.003082275390625, '0110101': 0.003082275390625, '1110011': 0.003082275390625, '0001010': 0.003082275390625, '1111100': 0.003082275390625, '1111011': 0.003082275390625, '1011010': 0.003082275390625, '0110011': 0.003082275390625, '1011001': 0.003082275390625, '0001100': 0.003082275390625, '1010100': 0.003082275390625, '1110010': 0.003082275390625, '0101011': 0.003082275390625, '1111111': 0.003082275390625, '0101111': 0.003082275390625, '0111010': 0.003082275390625, '0010100': 0.003082275390625, '1101001': 0.003082275390625, '0110000': 0.003082275390625, '1101010': 0.003082275390625, '0110111': 0.003082275390625, '0100111': 0.003082275390625, '1101101': 0.003082275390625, '1000011': 0.003082275390625, '1100111': 0.003082275390625, '0101100': 0.003082275390625, '1111000': 0.003082275390625, '0000101': 0.003082275390625, '0111101': 0.003082275390625, '0111110': 0.003082275390625, '0001011': 0.003082275390625, '0011000': 0.003082275390625, '1001011': 0.003082275390625, '0001000': 0.003082275390625, '1000110': 0.003082275390625, '0000011': 0.003082275390625, '1011110': 0.003082275390625, '1101100': 0.003082275390625, '0000000': 0.003082275390625, '0100011': 0.003082275390625, '1110110': 0.003082275390625, '0001111': 0.003082275390625, '1001110': 0.003082275390625, '1010000': 0.003082275390625, '1000000': 0.003082275390625, '0110100': 0.003082275390625, '0001001': 0.003082275390625, '0101000': 0.003082275390625, '0111100': 0.003082275390625, '1101111': 0.003082275390625, '1010110': 0.003082275390625, '1001111': 0.003082275390625, '0010010': 0.003082275390625}
# QEMCResult(optimizer_result= message: Maximum number of function evaluations has been exceeded.
#  success: False
#   status: 2
#      fun: 0.04253649525344372
#        x: [ 1.511e+00  6.188e+00 ...  2.915e+00  3.649e+00]
#     nfev: 1000
#    maxcv: 0.0, best_counts={'1010111': 0.03125, '1101110': 0.0302734375, '0011101': 0.025390625, '1110001': 0.0234375, '0100101': 0.01953125, '1001100': 0.0185546875, '1101000': 0.0185546875, '1010001': 0.017578125, '1111110': 0.0166015625, '1000111': 0.0166015625, '0000010': 0.0166015625, '0110001': 0.0166015625, '1100000': 0.015625, '1111101': 0.0146484375, '1011111': 0.0146484375, '1100110': 0.0146484375, '0100000': 0.0146484375, '1111001': 0.0146484375, '0100010': 0.0146484375, '1100100': 0.0146484375, '0001101': 0.013671875, '1110100': 0.013671875, '0110010': 0.013671875, '0000110': 0.0126953125, '0010111': 0.0126953125, '0100001': 0.0126953125, '1000101': 0.01171875, '0011001': 0.01171875, '1001001': 0.01171875, '0011110': 0.01171875, '1111010': 0.01171875, '0111001': 0.01171875, '0011010': 0.01171875, '1100011': 0.0107421875, '1010011': 0.0107421875, '1011101': 0.0107421875, '0100110': 0.0107421875, '0011011': 0.009765625, '0010000': 0.009765625, '1100001': 0.009765625, '0111011': 0.009765625, '0001110': 0.009765625, '1011000': 0.009765625, '1000100': 0.009765625, '0000001': 0.009765625, '0101010': 0.0087890625, '1011100': 0.0087890625, '0010101': 0.0087890625, '0000111': 0.0087890625, '0101110': 0.0087890625, '1000001': 0.0078125, '0010001': 0.0078125, '1110101': 0.0078125, '0101101': 0.0078125, '0010011': 0.0078125, '1011011': 0.0078125, '1010010': 0.0078125, '0111111': 0.0078125, '1101011': 0.0078125, '0101001': 0.0078125, '0111000': 0.0078125, '1010101': 0.0078125, '1001101': 0.0068359375, '1100101': 0.0068359375, '0000100': 0.003082275390625, '1100010': 0.003082275390625, '0110101': 0.003082275390625, '1110011': 0.003082275390625, '0001010': 0.003082275390625, '1111100': 0.003082275390625, '1111011': 0.003082275390625, '1011010': 0.003082275390625, '0110011': 0.003082275390625, '1011001': 0.003082275390625, '0001100': 0.003082275390625, '1010100': 0.003082275390625, '1110010': 0.003082275390625, '0101011': 0.003082275390625, '1111111': 0.003082275390625, '0101111': 0.003082275390625, '0111010': 0.003082275390625, '0010100': 0.003082275390625, '1101001': 0.003082275390625, '0110000': 0.003082275390625, '1101010': 0.003082275390625, '0110111': 0.003082275390625, '0100111': 0.003082275390625, '1101101': 0.003082275390625, '1000011': 0.003082275390625, '1100111': 0.003082275390625, '0101100': 0.003082275390625, '1111000': 0.003082275390625, '0000101': 0.003082275390625, '0111101': 0.003082275390625, '0111110': 0.003082275390625, '0001011': 0.003082275390625, '0011000': 0.003082275390625, '1001011': 0.003082275390625, '0001000': 0.003082275390625, '1000110': 0.003082275390625, '0000011': 0.003082275390625, '1011110': 0.003082275390625, '1101100': 0.003082275390625, '0000000': 0.003082275390625, '0100011': 0.003082275390625, '1110110': 0.003082275390625, '0001111': 0.003082275390625, '1001110': 0.003082275390625, '1010000': 0.003082275390625, '1000000': 0.003082275390625, '0110100': 0.003082275390625, '0001001': 0.003082275390625, '0101000': 0.003082275390625, '0111100': 0.003082275390625, '1101111': 0.003082275390625, '1010110': 0.003082275390625, '1001111': 0.003082275390625, '0010010': 0.003082275390625}, best_params=array([1.50982839, 6.18731884, 5.86727627, 7.18702114, 0.6944497 ,
#        4.23922344, 5.42950879, 4.67847432, 3.66401269, 0.84898879,
#        0.92522695, 5.25441547, 1.47046034, 5.93096819, 3.81881723,
#        5.35343394, 5.78305896, 1.20478899, 3.13623703, 4.35571931,
#        1.59498757, 4.5006178 , 6.81696128, 1.27684632, 2.34140021,
#        0.83295265, 4.17193964, 1.71017669, 3.39005397, 1.93173411,
#        4.80608426, 1.70471938, 1.01768334, 5.8892628 , 5.11961796,
#        4.177492  , 2.87259002, 2.92559277, 5.39026398, 3.61658456,
#        2.89519704, 0.96054163, 2.28570058, 3.12699885, 4.29330936,
#        3.70915737, 1.11680155, 4.6965959 , 0.08980573, 5.94640679,
#        5.22122422, 4.2403052 , 6.13198287, 3.8388949 , 5.14871761,
#        1.60099695, 5.44647651, 5.19354712, 1.10273911, 5.63729136,
#        3.04237752, 2.54431872, 1.06380598, 1.58224093, 4.41505107,
#        2.02616803, 1.40429952, 5.17364284, 6.047371  , 2.83819245,
#        5.83960099, 2.55804427, 1.57260453, 5.21260464, 5.2526398 ,
#        4.82965259, 0.75514704, 5.64072583, 3.72097398, 2.92850647,
#        0.79860476, 0.2895524 , 1.44180426, 3.05411461, 1.01310232,
#        4.18278875, 0.60296607, 4.77189778, 6.08420707, 5.58019427,
#        1.39613308, 4.05003484, 0.16141965, 2.85610685, 5.69121805,
#        4.88256621, 3.3346548 , 3.4236318 , 0.52743278, 0.07296526,
#        3.47630982, 0.57434752, 0.72298324, 1.71499185, 3.11958516,
#        2.88385224, 6.24600501, 5.55780518, 0.45396015, 1.84500149,
#        1.57345925, 3.14745658, 3.40674902, 2.9492547 , 3.92368036,
#        4.81917687, 5.19961331, 3.41615864, 5.40630531, 4.2288653 ,
#        4.50136396, 1.89120269, 3.75378595, 0.76148952, 2.40928077,
#        3.95243176, 5.81045257, 0.78376089, 1.83801355, 4.82239556,
#        3.84306146, 3.34644157, 0.22629305, 0.41630382, 1.76614024,
#        1.95965336, 0.88971749, 1.38412513, 4.65170605, 0.57421847,
#        2.28596333, 5.36943362, 2.58304919, 2.6781023 , 0.33975777,
#        0.27864281, 0.41496545, 5.88822327, 2.73574557, 5.67167228,
#        0.81727441, 0.91229959, 4.95207514, 2.4640483 , 4.00274111,
#        5.4876151 , 2.46170413, 0.61676952, 1.68032981, 0.70990402,
#        3.80687164, 5.49048793, 1.34013538, 1.71873597, 5.42535167,
#        4.96498124, 1.5124986 , 5.42326693, 5.79978996, 6.19844479,
#        5.30210426, 5.61637663, 1.27534363, 1.51799722, 0.70083247,
#        3.32620451, 3.82815922, 5.50026874, 5.50091252, 5.1145971 ,
#        3.09508937, 0.22314969, 4.12058307, 3.30265487, 0.35455574,
#        5.73417081, 0.3837327 , 6.23641677, 0.71214726, 6.24489385,
#        5.59806621, 2.24038389, 2.81760013, 0.05944965, 5.11591623,
#        0.97359477, 3.01072137, 4.35064063, 5.62344401, 0.19143235,
#        0.91496537, 2.96423704, 1.98317831, 5.3676151 , 3.4375229 ,
#        6.15784109, 3.377001  , 2.59268684, 2.91414127, 3.6467298 ]), best_cost_value=512, best_partition_bitstring='01100110001100100100100101011011101110011010111000010010101100101000101100000110011001100110011101101110101010110110000011000110', best_score=152)

# %%
plot_distribution(qemc_ml_version_res.best_counts, sort="value_desc")

# %%
qemc_iters = len(qemc_int.cut_scores)
qemc_ml_iters = len(qemc_ml_int.cut_scores)
iters_diff = np.abs(qemc_iters - qemc_ml_iters)
x = range(max(qemc_iters, qemc_ml_iters))

if qemc_iters > qemc_ml_iters:
    qemc_ml_int.cut_scores.extend(
        [qemc_ml_int.cut_scores[-1] for _ in range(iters_diff)]
    )
else:
    qemc_int.cut_scores.extend(
        [qemc_int.cut_scores[-1] for _ in range(iters_diff)]
    )


plt.plot(x, qemc_int.cut_scores, label="org_qemc")
plt.plot(x, qemc_ml_int.cut_scores, label="memory_limit_qemc")

plt.legend()

# %%
len(graph.edges)
# Out:
# 256
