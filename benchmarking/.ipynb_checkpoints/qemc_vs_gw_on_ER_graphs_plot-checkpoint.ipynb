# %%
root = "EXP_DATA/try_small_3/"

best_data_files_paths = [
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
]

# %%
import json

for best_data_json in best_data_files_paths:
    with open(best_data_json, "r") as f:
        d = json.load(f)
        
    print(d["conclusion"]["best_cut_score"])
# Out:
# 25
# 26
# 26
# 27
# 42
# 46
# 42
# 44
# 51
# 52
# 52
# 52
# 72
# 72
# 75
# 76
# 99
# 108
# 105
# 109

# %%
import numpy as np

optimal_cuts = np.array([30, 60, 70, 90, 120])
qemc_cuts = np.array([27, 46, 52, 75, 109])

# %%
qemc_cuts / optimal_cuts
# Out:
# array([0.9       , 0.76666667, 0.74285714, 0.83333333, 0.90833333])

# %%
import matplotlib.pyplot as plt

graphs_sizes = np.array([16, 20, 24, 28, 32])

plt.plot(graphs_sizes, qemc_cuts / optimal_cuts)
plt.plot(graphs_sizes, [1 for _ in range(5)])

# %%
 gw_max_cut(G0)
# Out:
# (26.3, 27.0)

# %%
df = pd.read_csv(
    "EXP_DATA/try_small_3/graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/data.csv"
)
df
# Out:
#       Unnamed: 0  sample_0_costs  sample_0_cuts  sample_1_costs
# 0              0        0.751420             73        0.450985  \
# 1              1        0.751420             73        0.450985
# 2              2        0.526335             76        0.447578
# 3              3        0.545251             82        0.448978
# 4              4        0.526335             76        0.447578
# ...          ...             ...            ...             ...
# 4995        4995        0.263530            109        0.279187
# 4996        4996        0.263531            109        0.279188
# 4997        4997        0.263530            109        0.279188
# 4998        4998        0.263530            109        0.279188
# 4999        4999        0.263531            109        0.279187
#
#       sample_1_cuts  sample_2_costs  sample_2_cuts
# 0                79        0.613332             68
# 1                79        0.613332             68
# ...

# %%
plt.plot(range(5000), df["sample_2_cuts"])

# %% [markdown]
# ---------

# %%
plt.plot([16, 20, 24, 28, 32], [50, 70, 90, 103, 120])

# %%
from gw_maxcut import brute_force_max_cut

brute_force_max_cut(G4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[105], line 3
#       1 from gw_maxcut import brute_force_max_cut
# ----> 3 brute_force_max_cut(G4)
#
# File ~/work/quantum_variational_combinatorial_optimization/qemc/benchmarking/gw_maxcut.py:42, in brute_force_max_cut(G)
#      40 for int_cut in range(1, 2**(n-1) + 1):
#      41     cut = int_to_binary(n, int_cut)
# ---> 42     value = cut_cost(cut * 2 - 1, L)
#      44     if value > max_cut_value:
#      45         max_cut_value = value
#
# KeyboardInterrupt:

# %% [markdown]
# -----------------------

# %%
root = "EXP_DATA/try_small_3/"

best_data_files_paths = [
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_0/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_1/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_2/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_3/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_2/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_4/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_6/shots_None/best_data.json",
    f"{root}graph_G_4/backend_statevector_simulator/blue_nodes_None/num_layers_8/shots_None/best_data.json",
]

# %%
num_instances = 5
num_samples = 3
layers = [2, 4, 6, 8]

for graph_index in range(num_instances):
    for num_layers in layers:
        path = f"{root}graph_G_{graph_index}/backend_statevector_simulator/blue_nodes_None/num_layers_{num_layers}/"
        
        with open(f"{path}shots_None/best_data.json", "r") as f:
            best_data = json.load(f)
            
        best_cut = best_data["conclusion"]["best_cut_score"]
        
        mean_best_cuts = 0
        for sample_id in range(num_samples):
            mean_best_cuts += best_data[f"sample_{sample_id}"]["best_score"]
        mean_best_cuts /= num_samples
        
        print(mean_best_cuts)
        
        nx.from_grapm
        gw_max_cut()
# Out:
# 22.666666666666668
# 25.333333333333332
# 25.333333333333332
# 26.333333333333332
# 41.333333333333336
# 41.666666666666664
# 41.0
# 43.666666666666664
# 50.0
# 50.333333333333336
# 50.666666666666664
# 50.333333333333336
# 65.66666666666667
# 69.66666666666667
# 74.33333333333333
# 73.66666666666667
# 97.66666666666667
# 100.0
# 104.0
# 106.66666666666667

# %%
nx.read_graphmlsdad
